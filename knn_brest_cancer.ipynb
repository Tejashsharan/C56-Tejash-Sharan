# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejashsharan/C56-Tejash-Sharan/blob/main/knn_brest_cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/content/breast-cancer.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df = df.drop(['id'] ,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.iloc[:,1:],df.iloc[:,0], test_size=0.2, random_state = 2)

# %%
x_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 560        14.05         27.15           91.38      600.4          0.09929
# 428        11.13         16.62           70.47      381.1          0.08151
# 198        19.18         22.49          127.50     1148.0          0.08523
# 203        13.81         23.75           91.56      597.8          0.13230
# 41         10.95         21.35           71.90      371.1          0.12270
# ..           ...           ...             ...        ...              ...
# 299        10.51         23.09           66.85      334.2          0.10150
# 534        10.96         17.62           70.79      365.6          0.09687
# 493        12.46         12.83           78.83      477.3          0.07372
# 527        12.34         12.27           78.94      468.5          0.09003
# 168        17.47         24.68          116.10      984.6          0.10490
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
from sklearn.metrics import accuracy_score
y_pred = knn.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9912280701754386

# %%
results = []

for i in range(1, 16):  # Testing k from 1 to 15
    model = KNeighborsClassifier(n_neighbors=i)  # Create the KNN model with i neighbors
    model.fit(x_train, y_train)                  # Train the model
    y_pred = model.predict(x_test)               # Make predictions
    accuracy = accuracy_score(y_test, y_pred)   # Calculate accuracy
    results.append((i, accuracy))                # Store the k value and corresponding accuracy

# Print the results
for k, acc in results:
    print(f"k={k}: Accuracy={acc:.2f}")
# Out:
# k=1: Accuracy=0.96
# k=2: Accuracy=0.97
# k=3: Accuracy=0.99
# k=4: Accuracy=0.97
# k=5: Accuracy=0.97
# k=6: Accuracy=0.97
# k=7: Accuracy=0.97
# k=8: Accuracy=0.97
# k=9: Accuracy=0.97
# k=10: Accuracy=0.97
# k=11: Accuracy=0.97
# k=12: Accuracy=0.97
# k=13: Accuracy=0.97
# k=14: Accuracy=0.96
# k=15: Accuracy=0.96
